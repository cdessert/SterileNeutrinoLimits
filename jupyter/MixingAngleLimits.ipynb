# %%
# %matplotlib inline
from numpy import *
import matplotlib.pyplot as plt
import sys
sys.path.append('../python')
from PlotFuncs import SterileNeutrinoMixing

# %%
fig,ax = SterileNeutrinoMixing.FigSetup(Shape='Rectangular',mathpazo=True)
SterileNeutrinoMixing.DessertScience2020(ax)
SterileNeutrinoMixing.PerezBulge2019(ax)
SterileNeutrinoMixing.BulbulHalo2020(ax)
SterileNeutrinoMixing.MiscXMMChandra(ax)
SterileNeutrinoMixing.AbajAndromeda2013(ax)

SterileNeutrinoMixing.DMUnderproduction(ax)
SterileNeutrinoMixing.DES_Subhalo_Counts(ax)
